# %%
# !pip install yfinance==0.2.4

# %%
import yfinance as yf
import pandas as pd

# %%
apple = yf.Ticker("AAPL")

# %%
import json
with open('apple.json') as json_file:
    apple_info = json.load(json_file)
    
apple_info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
type(apple_info)
# Out:
# dict

# %%
apple_info.keys()
# Out:
# dict_keys(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city', 'phone', 'state', 'country', 'companyOfficers', 'website', 'maxAge', 'address1', 'industry', 'ebitdaMargins', 'profitMargins', 'grossMargins', 'operatingCashflow', 'revenueGrowth', 'operatingMargins', 'ebitda', 'targetLowPrice', 'recommendationKey', 'grossProfits', 'freeCashflow', 'targetMedianPrice', 'currentPrice', 'earningsGrowth', 'currentRatio', 'returnOnAssets', 'numberOfAnalystOpinions', 'targetMeanPrice', 'debtToEquity', 'returnOnEquity', 'targetHighPrice', 'totalCash', 'totalDebt', 'totalRevenue', 'totalCashPerShare', 'financialCurrency', 'revenuePerShare', 'quickRatio', 'recommendationMean', 'exchange', 'shortName', 'longName', 'exchangeTimezoneName', 'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 'quoteType', 'symbol', 'messageBoardId', 'market', 'annualHoldingsTurnover', 'enterpriseToRevenue', 'beta3Year', 'enterpriseToEbitda', '52WeekChange', 'morningStarRiskRating', 
# ...

# %%
apple_info['country']
# Out:
# 'United States'

# %%
apple_share_price_data = apple.history(period='max')
apple_share_price_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.099584  0.100017  0.099584  0.099584  469033600
# 1980-12-15 00:00:00-05:00  0.094821  0.094821  0.094388  0.094388  175884800
# 1980-12-16 00:00:00-05:00  0.087893  0.087893  0.087461  0.087461  105728000
# 1980-12-17 00:00:00-05:00  0.089625  0.090058  0.089625  0.089625   86441600
# 1980-12-18 00:00:00-05:00  0.092224  0.092657  0.092224  0.092224   73449600
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# 1980-12-15 00:00:00-05:00        0.0           0.0
# 1980-12-16 00:00:00-05:00        0.0           0.0
# 1980-12-17 00:00:00-05:00        0.0           0.0
# 1980-12-18 00:00:00-05:00        0.0           0.0

# %%
apple_max = apple_share_price_data['Close'].max()
apple_share_price_data[apple_share_price_data['Close']==apple_max]
# Out:
#                                  Open        High         Low      Close  \
# Date
# 2022-01-03 00:00:00-05:00  176.290475  181.296759  176.171519  180.43428
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-01-03 00:00:00-05:00  104487900        0.0           0.0

# %%
apple_share_price_data.reset_index(inplace=True)
apple_share_price_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 1980-12-12 00:00:00-05:00  0.099584  0.100017  0.099584  0.099584
# 1 1980-12-15 00:00:00-05:00  0.094821  0.094821  0.094388  0.094388
# 2 1980-12-16 00:00:00-05:00  0.087893  0.087893  0.087461  0.087461
# 3 1980-12-17 00:00:00-05:00  0.089625  0.090058  0.089625  0.089625
# 4 1980-12-18 00:00:00-05:00  0.092224  0.092657  0.092224  0.092224
#
#       Volume  Dividends  Stock Splits
# 0  469033600        0.0           0.0
# 1  175884800        0.0           0.0
# 2  105728000        0.0           0.0
# 3   86441600        0.0           0.0
# 4   73449600        0.0           0.0

# %%
apple_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#dir(apple)

# %%
apple.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-05-06 00:00:00-04:00    0.230000
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# Name: Dividends, Length: 79, dtype: float64

# %%
apple.dividends.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import json
with open('amd.json') as json_file:
    amd_info = json.load(json_file)
    
amd_info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 15500,
# ...

# %%
print(amd_info['country'], amd_info['sector'])
# Out:
# United States Technology

# %%
amd = yf.Ticker('AMD')
amd
# Out:
# yfinance.Ticker object <AMD>

# %%
amd_share_price = amd.history(period='max')
amd_share_price
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-03-17 00:00:00-05:00    0.000000    3.302083    3.125000    3.145833
# 1980-03-18 00:00:00-05:00    0.000000    3.125000    2.937500    3.031250
# 1980-03-19 00:00:00-05:00    0.000000    3.083333    3.020833    3.041667
# 1980-03-20 00:00:00-05:00    0.000000    3.062500    3.010417    3.010417
# 1980-03-21 00:00:00-05:00    0.000000    3.020833    2.906250    2.916667
# ...                               ...         ...         ...         ...
# 2023-05-18 00:00:00-04:00  103.980003  108.099998  103.930000  107.930000
# 2023-05-19 00:00:00-04:00  106.360001  107.290001  104.620003  105.820000
# 2023-05-22 00:00:00-04:00  104.680000  108.790001  103.489998  108.000000
# 2023-05-23 00:00:00-04:00  107.250000  110.989998  107.190002  108.120003
# 2023-05-24 00:00:00-04:00  105.980003  108.910004  105.639999  108.269997
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
amd_share_price[amd_share_price['Close']==amd_share_price['Close'].max()]
# Out:
#                             Open        High         Low       Close  \
# Date
# 2021-11-29 00:00:00-05:00  157.5  162.509995  156.100006  161.910004
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-11-29 00:00:00-05:00  57438900        0.0           0.0

# %%
amd_info['sector']
# Out:
# 'Technology'

# %%
amd_share_price.iloc[0]['Volume']
# Out:
# 219600.0
